# %%
from IPython.display import Image

# %% [markdown]
# #### Trees

# %%
Image('Hierarchy of Tree Structures.PNG')

# %% [markdown]
# # Proper or full binary tree
#     - Each nodes has either 0 or 2 children

# %% [markdown]
# # Decisions trees are a subset of bianry trees

# %% [markdown]
# # Preorder traversal

# %%
Image('PreOrderTraversal.PNG')

# %% [markdown]
# # Postorder traversal

# %%
Image('PostOrderTraversal.PNG')

# %% [markdown]
# # In order traversal : specific to binary trees

# %%
Image('InOrderTraversal.PNG')

# %% [markdown]
# # Binary Search Tree

# %%
Image('BST.PNG')

# %% [markdown]
# # Search in BST : running time

# %%
Image('RunningTimeofBST.PNG')

# %% [markdown]
# # Properties of Binary Trees

# %%
Image('PropertiesofBinaryTrees.PNG')
